# %%
import re
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk import tokenize 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from heapq import nlargest

# %%
stop_words = set(stopwords.words('english'))
#print(stop_words)
lemmatizer = WordNetLemmatizer()

def read_from_file(filename):
    df = pd.read_csv(filename, index_col=0)
    return df

# Data exploration
def data_exploration(dataset):
    dataset.isnull().sum() # all zeros
    dataset.business_id.nunique() # 284
    dataset.name.nunique() # 271
    dataset.groupby('name').size().sort_values(ascending=False)
    dataset.groupby('business_id').size().sort_values(ascending=False).head()

def clean_dataset(dataset):
    reviews_by_businessid = dataset.groupby('business_id').apply(lambda x: x['text'].unique()).to_frame(name='review_list')
    reviews_by_businessid = reviews_by_businessid.reset_index()
    reviews_by_businessid['review_list'] = reviews_by_businessid['review_list'].apply(lambda x: ' '. join(x))
    return reviews_by_businessid
    
def sent_preprocess(sent):
    tokens = [word for word in word_tokenize(sent)]
    filtered_tokens = [token.lower() for token in tokens if re.match("^[A-Za-z-]*$", token)]
    lemmatized_tokens = [lemmatizer.lemmatize(t, 'v') for t in filtered_tokens]
    #final_tokens = [s for s in lemmatized_tokens if s not in stop_words]
    return ' '.join(lemmatized_tokens)

def preprocess(reviews_by_businessid):
    # remove head() later
    reviews_dict = dict(zip(reviews_by_businessid.head(1).business_id, reviews_by_businessid.head(1).review_list))
    sentences_dict = {}
    processed_sent_dict = {}
    
    for bi, text in reviews_dict.items():
        sentences_dict[bi] = sent_tokenize(text)
    
    for bi, sent_list in sentences_dict.items():
        new_sent_list = set()
        
        for sent in sent_list:
            processed_sent = sent_preprocess(sent)
            new_sent_list.add(processed_sent)
        
        processed_sent_dict[bi] = new_sent_list
    
    return processed_sent_dict, sentences_dict

def select_pos_reviews(processed_reviews, original_reviews):
    pos_reviews_dict = {}
    
    sid = SentimentIntensityAnalyzer()
    
    for bi, sent_list in processed_reviews.items():
        pos_sentences = set()
        pos_scores = []
        
        for idx, sentence in enumerate(sent_list):
            ss = sid.polarity_scores(sentence)
            
            #pos_score = ss['pos']
            #neg_score = ss['neg']
            #neu_score = ss['neu']
            compound_score = ss['compound']
            #pos_scores.append(compound_score)
        
            if compound_score >= 0.05:
                original_sentence = original_reviews[bi][idx]
                pos_sentences.add(re.sub('\s+', ' ', original_sentence).replace("\\", ""))
                #print('original sentence: ', original_sentence)
                #print('processed sentence; ', sentence)
        
        #indices = nlargest(10, range(len(pos_scores)), key=lambda idx: pos_scores[idx])
        pos_reviews_dict[bi] = pos_sentences
    
    return pos_reviews_dict

# %%
fn = "csv_reviews_mesa.csv"
mesa = read_from_file(fn)

# change assignment later
selected_businesses = mesa
reviews_by_businessid = clean_dataset(selected_businesses)

processed_reviews, original_reviews = preprocess(reviews_by_businessid)
res = select_pos_reviews(processed_reviews, original_reviews)
res
# Out:
# {'-3oxnPPPU3YoxO9M1I2idg': {'"Wine country" and " besto pesto" gluten free pizza plus a bunch of extra meat veggies and cheeses!',
#   '"Yes hello, i would like a cheese pizza with everything you have to eat in this building put on the pizza as a topping for no extra charge" that\'s how this place works.',
#   '$2 domestics during weekday lunch.',
#   '(Cream soda and ginger ale are the ones I tried) YUM!',
#   '(My favorite brand) Nice Staff.',
#   "10 minutes pass and I still haven't been acknowledged.",
#   '2 Stars.',
#   '2 pizzas 2 sodas.....22.00 Please do mistake this for good pizza from your local pizzeria.',
#   '3/5 stars until this is addressed.',
#   '4 beers and a coke for $34.',
#   '6/5 stars!',
#   ':( They were awesome and you could build your own pizza like at mod.',
#   'A definite must-visit.',
#   'A great step up from your hole in the wall pizza joint.',
#   'A part of me wanted to go nuts, but the other part of me was lazy and really hungry, so we chose to go with 2 different pre-made pies from the "wall of fame".',
#   'A staff member finally asked what the name on my order was and I told them.',
#   'A tad pricey for what you actually get; however, i would definately come back again.',
#   'Add any toppings and combinations, which is great if you are a newbie or indecisive.',
#   "After awhile they'll be 3 pizza places in the shopping center.",
#   'After looking for a few minutes, my order was found in the warming oven.',
#   'All 3 have to work together.',
#   'All around, the staff was super friendly and made the ordering process very clear and easy.',
#   'All pizzas are thin crust.',
#   'All the pizza flavored are good and you can customize it the way you want .',
#   "Also before we left they handed out frisbee's and water bottles that had their logo on it.",
#   'Also great crust.',
#   'Amazing place food is great.',
#   'An amazing pie with fresh ingredients delivered from an amazingly friendly staff.',
#   'An entree salad is $8 and comes with whatever you want: Italian sausage, pepperoni, sliced mozzarella, blue cheese crumbles, parmesan, cheddar, carmelized onions, mushrooms, red peppers, chopped tomatoes, raw red onions, black & green olives, artichokes and more!',
#   'And adult beverages too.',
#   'And even though we live in downtown Phoenix, we decided to endure the insane 20 min.',
#   "And it's always clean!",
#   'Another thing I really appreciated was the employee switched out his gloves before making my pizza so as not to contaminate mine with the cheese/meat from the previous pizza.',
#   'Anything with the Spicy Cilantro Lime sauce is the bomb!',
#   'As compared to other like pizza joints (e.g.',
#   'As far as toppings go, they are endless.',
#   'At 6:15 (25 minutes after I arrived) a man behind me in line spoke up and said that he had been waiting awhile.',
#   'Awesome pizza.',
#   'Bacon, grilled chicken etc...',
#   'Being the meat-lover that I am, I definitely favored the Meaty Italiano.',
#   'Best pizza joint around!!!!',
#   'Besto Pesto is my favorite!',
#   'Bon Appetit!',
#   "Build your own and don't brake the bank.",
#   'But if you load up the toppings they will serve the pizza slightly under cooked.',
#   "But the toppings don't make a pizza.",
#   'But those were such small things that I can give it 5 stars.',
#   "But when I asked for a to go piZza and sat down they put it on a metal pizza plate and brought it to my table..... okay so this tells me you couldn't be bothered to listen to me.",
#   'C and I decided to stop by on our way to his rehearsal.',
#   'C had a chocolate milk ($1.79) and I had the China Mist Tea ($2.19).',
#   "C's was basically a meat lovers.",
#   'Check out the bathroom signs!',
#   'Cheese and pepperoni ok.',
#   'Chipotle style ordering.',
#   'Choice of 7 or 11 inch pizzas with a max price of $7.99.',
#   'Clean Dining Room.',
#   'Clean tables with variety of types like booths, high too vs low top tables!',
#   'Cool concept!',
#   "Couldn't ask for any other place for a free pizza for your birthday.",
#   'Dare I say, the best pizza place I have ever been to?',
#   'Definitely coming here from now on anytime I crave pizza!',
#   'Definitely recommend them and will be back more!',
#   "Definitely the best make it your own type pizza place I've been to, beats Mod Pizza by a mile!!",
#   'Delicious food.',
#   "Delicious pizza's with all the extra toppings you could want.",
#   "Didn't want to get sick, so we left.",
#   'Eh.',
#   'Eklectic Pie The staff are friendly, the atmosphere is fun and the food is good.',
#   'Ekletic Pie is now among my top favorite, the ambiance is unique and comfortable.',
#   'Employees are very nice but very slow.',
#   'Even with great service I would not go back.',
#   'Every time my wife and I go there, everyone is happy and smiling.',
#   'Everyone is super friendly and the pizza is delicious!',
#   'Everyone was pleasant, engaging with customers, happy, and hard working individuals.',
#   'Everyone who works here is amazing too.',
#   "Everything I've had has been amazing!",
#   'Everything about this place is really slick.',
#   'Everything is fresh and made to order.',
#   'Excellent customer service!!!!',
#   'Excellent pizza and service!',
#   'Families were eating together and the owners (who seemed to be anyways) would mingle and laugh along with everyone.',
#   'Family environment!',
#   'Fantastic service from the top down!',
#   'Fast service!',
#   'Fast service.',
#   'Finally went in, the place was much larger than I expected, nice atmosphere, friendly & helpful employees and best of all, food was great.',
#   "First let me say i do love all the build your own pizza places - it's a trend but as someone with food allergies, it makes ordering easy.",
#   'For any of the meat that I love...extra!',
#   'Found our new date night place!',
#   'Fresh ingredients, great price, crust is good--a little thin for my taste but next time I will get the double crust for just a buck more.',
#   'Fresh ingredients, great tasting pizza, beer and soda with real cane sugar.',
#   'Friendly staff.',
#   'Garlic parmesan knots with a side of marinara is $3.',
#   "Get the roasted garlic, it's heavenly!!!",
#   "Give it a try, I don't think you'll be disappointed.",
#   'Good Toppings.',
#   'Good concept Horrible execution.',
#   'Good had excellent flavor.',
#   'Good job guys!',
#   'Good pizza made quickly, without skimping on quality.',
#   'Good specials M-W.',
#   'Good, nothing brand new to the industry but very good pizza and we will be back.',
#   'Great atmosphere, good quality toppings, and friendly staff.',
#   'Great crust, which in my mind makes or breaks a pizza, great flavor.',
#   'Great pizza for a great price.',
#   'Great place!',
#   'Great prices, great staff and amazing tasting pizza.',
#   'He goes back AGAIN and RE-EXPLAINS what he wants and they finally give him the right box.',
#   "He saw the sign the last time we drove thru Raising Cane's so we decided to give it a shot.",
#   'He was a fan.',
#   'He was apologetic and very friendly.',
#   'Heaven!!',
#   'Highly recommend trying it.',
#   'However, the service was not as good.',
#   'I added jalapeños and it was perf.',
#   "I also appreciated that I don't have to walk to the counter to grab my pizza rather I can just take in the atmosphere and have it brought to the table!",
#   'I also loved that you can get addtional toppings like spinch, basil, vinaigrette, etc when the pizza comes out of the oven.',
#   "I also noticed there was no corn mean on the dough.... To me that's what makes a pizza, also they use ovens like dominos or pizza hut would use instead of a fire oven or brick oven which changes the taste completely.",
#   'I am a plain pizza person so I only get pepperoni and my fiance gets meat lovers, he enjoyed his pizza although for myself it came out soggy and floppy.',
#   'I am definitely bring more friends, family, and co-workers to this joint.',
#   'I am not a pizza person.',
#   "I appreciate that there's competition in the DIY pie arena.",
#   'I asked if i could just place a telephone order but was quickly dismissed.',
#   "I believe its called Boylan's soda.",
#   'I came back again.',
#   "I can't wait for my next trip to Mesa so I can come back!!!",
#   "I can't wait to come back to try another.",
#   "I did like it, but it's now closed.",
#   "I didn't care for the sauce either.",
#   "I didn't however like that the meats were ice cold i.e.",
#   "I don't drink soda but I think it's cool that they serve something other than the big two soda companies.",
#   "I don't have to say I'll have that but without this and that...",
#   "I don't know how to put this exactly but I'll give it a try.",
#   'I felt like the different sauces were not visible unless you looked at the menu around the corner.',
#   'I go crispy 1&1/2 times thru oven for that bomb crisp.',
#   'I got the Potato Skin pizza... OMG it was amazing!!!',
#   'I got the loaded potato skin pizza, and sgt.',
#   'I had ordered online an HOUR prior.',
#   'I had the Italian white wedding which was good, although they could have cooked it a little longer and my Husband had the gyro, which he thought was good.',
#   'I had the chairman chow pizza and it was pretty tastey.',
#   'I had the lunch special of a 7" pie and a side ceasar salad.',
#   'I hate to bash a place but this place needs to rethink there approach to pizza .',
#   'I have been twice in the last month.',
#   'I have eaten here twice now the first time I got the wine country which is a delicious pear spinach gorgonzola pizza.',
#   'I have eaten there several times now and every time its been a thumbs up.',
#   'I have suggested this place to friends and coworkers without hesitation.',
#   'I have to say I was super impressed!',
#   'I highly recommend this pizza restaurant.',
#   'I highly recommend this place.',
#   'I kept having to repeat my toppings.',
#   'I kept seeing this place when I would drive by and always wanted to try it.',
#   'I know these guys have been here awhile, and it sucks for them to see another EXACT replica pizza place going up `100 feet away and a MAJOR chain going in across the parking lot.',
#   'I like the Creme soda, personally.',
#   'I like thin pizza a lot but this one is so thin it bends and toppings fall off when you try and pick up a slice.',
#   "I love that they don't charge for each topping, it's all one price.",
#   "I love this place, it's the only place I go to for pizza these days.",
#   'I love this place.',
#   'I love veggie toppings and they had a ton of veggies in addition to vegan cheese which was great.',
#   'I only ordered a salad & was thrilled to be able to put as many toppings on as I liked.',
#   'I ordered 4 toppings and they were barely there, a lot of empty space between toppings.',
#   'I ordered the pizza and was amazed by the flavor.',
#   'I really appreciate the GF pizza option as I have a family member with Celiac disease.',
#   "I really like the concept & the staff was super nice but they couldn't hear a word I said.",
#   'I really like the feel of this place.',
#   'I recommend the wine country (mine) and the Besto pesto (his).',
#   'I saw several I want to try.',
#   'I showed up at 5:50pm and went to the carry out counter.',
#   'I stopped in a few weeks ago and ordered a half loaded potato skin and a half meaty Italiano minus olives pizza ($7.99), and had a San Tan Oktoberfest ($4.39) to wash it all down.',
#   'I tried the Orange Blossom wheat beer and my husband tried the birch beer (which is non-alcoholic and similar to root beer), and we both loved our choices!',
#   "I understand that most stuff gets cooked after you order it but if your having a salad, cold meats don't really work.",
#   'I usually get the pepperoni pizza with Caesar salad.',
#   'I usually only go to fired pie of mod Pizza, but this place is just as, if not better than those places.',
#   'I waited 10 minutes again and still received the error.',
#   'I was a first timer and they deserve more than 5 stars!',
#   'I was very impressed, from walking in to leaving I got great service, a comfortable dining experience, and PHENOMENAL pizza.',
#   'I was wondering why the place was empty, but when we got our food I began to understand.',
#   'I went here to get my son something to eat and decided to get my own pizza since I saw they had vegan options.',
#   'I went in and ordered a gluten-free pepperoni pizza.',
#   "I went to grab a bite to eat with low expectations since I haven't had the best luck with this style restaurant, but I was surprised by the taste and variety of options!",
#   'I wish they had one in east mesa.',
#   'I wish, however, that they offered ranch as a side in the end.',
#   'I would definitely recommend this place.',
#   'I would hear how yummy it was so I decided to get it delivered through grub hub.',
#   'I would recommend this unique spot to anyone!!',
#   "I'd hate to see what happens when they're actually busy.",
#   "I'll be back, my kids like it better than the other we've been too.",
#   "I'll start with the good - the food is undeniably fantastic.",
#   "I'm anxious to try the pizza next time.",
#   "I'm baffled right now.",
#   "I'm not blown away by any means.",
#   "I'm not sure how these guys stay in business so just out of guilt I always end up buying drinks or a side (the wings and skins are fantastic!).",
#   "I'm sure the ingredients are as fresh as all the other BYOP places.",
#   "I've been here about a dozen times since they opened.",
#   "If I had to pay $19 for them I'd be more disappointed.",
#   "If they do (since they offer salads) they didn't make it clear.",
#   'If they only used a dough that is thicker and bubbles up.....maybe.',
#   "If you have a family that has mixed taste buds when it comes to pizza this for sure would be good for y'all.",
#   'If you live in Mesa or want to hang out with the new pizza kid on the block, go check out Eklectic Pie!',
#   "If you're out walking (like my husband and i were 4.5miles at that point) and you don't want heavy food then a small pizza and a small salad does the job.",
#   "If you've got a movie you're trying to make, plan for at least 45-60 minutes!",
#   'Ingredients are so fresh and their desserts are delicious!!',
#   'Inside, things are cool, industrial, and unusual.',
#   "Instead it serves Boylan's pure sugar cane soft drinks.",
#   'Interesting dining concept but the end product does not impress.',
#   'It felt thought-out and meticulous.',
#   'It is a little bit crispier since they don\'t "oven bake" it but rather use one of those pizza conveyer ovens.',
#   'It is a refreshing/new way to order pizza.',
#   'It is very comparable to MOD including some of the sauces.',
#   'It seemed they closed the Stapley location and I have not yet had the chance to go to Chandler.',
#   'It was clean and very trendy decor!',
#   'It was cooked to perfection and ready to eat in about three minutes.',
#   'It was good but I would drive further to another place with the same concept next time.',
#   'It was nice that the person making the pizza change their gloves to make sure there was no gluten on it and made the gluten-free pizza for me.',
#   'It was still amazing!',
#   'It was very fast and everything was exactly how I ordered it.',
#   'It was very good.',
#   "It would have been if the crust wasn't like a wet piece of Lavosh.",
#   "It's Sooo delicious.",
#   "It's a fairly new place & I really didn't realize it was a Pizza Place until I received a coupon in the mail.",
#   "It's a five star in my book!",
#   "It's a really cool spot and I'll definitely be back.",
#   "It's a shame becuase I wanted to really like this place.",
#   "It's actually really good.",
#   "It's good, it's fun.",
#   "It's like subway but for pizza.",
#   "It's like the subway of pizzas as you pay one price and can heap toppings to your hearts delight and all for only nine bucks!",
#   "It's not fancy, but it is fresh, fast, great employees and consistently so.",
#   "It's not that she placed too little...she placed a lot...it just took FOREVER.",
#   "It's very modern but homey as well.",
#   'Just give them the name on the loyalty account.',
#   'KUDOS!!!',
#   'Like I said ingredients were good, crust was not, not at all!!',
#   'Like the prices too!',
#   "Looking at the photos posted by other reivewers I'm thinking maybe we caught them on their off day.",
#   'Lousy Crust.',
#   'Love it.',
#   'Love love love love love.',
#   'Love that they have a wide variety if food (potato skins, sandwiches, dessert) and also love the playing cards given to mark your order number.',
#   'Love the bacon, pulled pork and roasted potatoes.',
#   'Love this place.',
#   "MOD pizza would use a fake wood/brick fire stove or whatever but the crust is always soggy since it's never left there in time.",
#   'Made a very disappointing end to a good first impression.',
#   'Makes it a great place to eat with the family.',
#   'Marguerita pizza was a little soggy, too much marinara.',
#   'Maybe the ingredients were fresh, but why would it matter.',
#   'Monday pizza nights are now scheduled at Eclectic!',
#   'My 11 year old son ate two 7 inch pizzas!',
#   'My brother walked up to the table and asked for a to go box and explained the issue.',
#   'My fiance and I came across a project pie in Vegas and fell in love with the concept, so when we saw this opened up right down the street from the house we were all over it.',
#   'My friend said its good.',
#   'My husband and I came here a couple weeks ago.',
#   'My husband and I were here recently and really enjoyed it!',
#   'My only other thing would be is, on a slow day or time, the music should be played a little lower being your almost yelling at the service worker.',
#   'My pizza was tasteful but not enough for the price, cracker crust assembly pizza which they cant cut pizza correcly so trying to take it apart was a mess.',
#   'My wife and I ate here for the first time and we were thoroughly impressed.',
#   'My wife and I came here for the first time and loved it!',
#   'My wife and I will be coming back time and time again and will recommend this place to everyone we know So numerous of these types of pizza places are popping up all over the valley.',
#   'My wife had the meat lovers?',
#   'Nice Facility.',
#   'Nicely decorated place.',
#   'No dessert this go around, but next time for sure.',
#   'No extra charge!',
#   'No extra cost for toppings!!!!',
#   'No one can touch the amazing pies at Eklectic Pie!!!!!',
#   'Not a bad place for pizza but not the best either.',
#   'Not a good first impression here Love a real gluten-free option for pizza.',
#   'Not expensive at all!',
#   'Not impressed at all!',
#   'Not sure if they need more ovens, more employees, or an espresso machine to get their staff moving, but something has to give.',
#   'Not totally crazy about that.',
#   'Not your usual soda choices.',
#   'Now the taste of the toppings were fine.',
#   "Now, we can each get our own pizzas with whatever we want and it's super affordable.",
#   'Oh, and the beer and wine choice... awesome.',
#   'On the plus side, they have birch beer (kind of like root beer).',
#   'Once I got home, I had further realized that they did not even include the right sauce on my pizza.',
#   'Once in line, you get the option of 1. choosing your pizza size (7" or 11"), 2. picking your sauce and 3. mixing up a variety of awesome ingredients at no extra charge.',
#   'Ordered online--menu stated a meatball sandwich came with a Caesers salad--uh no!',
#   'Ordered three of their pies and good flavor and good crust.',
#   'Other than that everything is pretty good taste and price wise.',
#   'Overall I would recommend checking this place out.',
#   'Overall you walk through a line and pick your toppings, nice thing is all toppings included in the price of the crust size so, load up!',
#   'Pepper.',
#   'Pizza is about fire and stone.',
#   'Pizza was awesome and so was the staff!',
#   'Pizza was great.',
#   'Pizza.....meh?',
#   'Pizzas are tiny and the salad even tinier.',
#   'Price was about normal for what you would consider... family of 5 (mom, dad 3 kids) about $40 (including the pint of IPA I enjoyed... Life is good you know... enjoy it!',
#   'Price: Very reasonable!',
#   'Prices are way to high for the small amount of food received.',
#   'Pro tip: ask for extra cook on loaded pies The cowboy barbeque pizza was delicious.',
#   "Probably not a place I'd go again but its not bad.",
#   'Quick, easy, tasty, and just the right size for everyone to have their own pizza.',
#   'Rather than complain, we ate our meal.',
#   'Really no healthy choices :( I ended up taking the salad home & using dressing from another restaurant.',
#   'Restaurant was very clean and the food was a good value for the money.',
#   'Right away I was greeted by the employees and I really like the interior.',
#   'SERIOUSLY?',
#   'Sauce -excellent Cheese- so/so Crust- ok Not crazy expensive, ok value Enjoy their custom pizzas.',
#   'Sauce was excellent, cheese ok not good or horrible.',
#   'Sauce.',
#   'Service can be a little slow.',
#   'Service was awesome, fresh ingredients, all organic.',
#   'Service was fast.',
#   'She also had a few different meats and lots of veggies.',
#   "She just finished stocking pepperoni and I don't want that in my food.",
#   'She placed it on a tablespoon at a time with the giant ladle.',
#   'She said hers was great as well.',
#   'Shut the front door!',
#   'Since I got exactly what I wanted, i really enjoyed my pie.',
#   "Since I ordered online and it was my first order, I received a free dessert and I chose s'mores pie--I'm just glad I didn't pay for it because it tastes terrible.",
#   'Small pizza and side salad for around seven dollars which is plenty to fill up on.',
#   'So I have been to many build your own pizza places and this one disappointed me.',
#   "So I've been to a lot around the valley and Eklectic Pie is my favorite - the best choice of topping anywhere.",
#   'So fast!!!!!',
#   'So friendly and helpful.',
#   'So happy to come across this little gem!',
#   "So now I'm upset and considering just leaving but I had prepaid for my pizzas.",
#   'So...I paid full price for cold, cardboard-like pizza after waiting nearly 40 minutes.',
#   'Soggy, no support for the ingredients.',
#   'Sorry, no joke, the rest of the pizza joints around here should just close up.',
#   'Sounds good right?',
#   'Staff was friendly and efficient...ordered the wine country and pesto chicken pizza.',
#   'Staff was friendly and prices were reasonable...will be back and looking forward to trying out their beverages...both adult and sodas/China Mist teas!!!',
#   'Standard price for the size of your choice (7" or 11") and all the toppings you want at no additional charge.',
#   'Stopped in for my first time because I had a coupon in the mail for an 11" pizza ($6.99) which fully fed 2 people.',
#   'Such a great atmosphere!!',
#   'Such good flavor.',
#   'Super creative and I love the local ingredients.',
#   'Suuuuper slow.',
#   'THANK YOU Yelp!',
#   'THAT IS AMAZING!',
#   'THUMBS UP EKLECTIC PIE!!',
#   "Take out, eat in, it doesn't matter.",
#   'Taste is on point along with quality, I enjoyed everything this eclectic pie had to offer.',
#   'Taste was great, nice thin crust, everything tested fresh.',
#   'Tasty pizzas with fresh ingredients, friendly service, and craft brews makes this place a trifecta of excellence!',
#   'Tatyana Leija and Hayley Stout are unbelievable behind the counter.',
#   'Thank you owner of this wonderful mouth play-land.',
#   'Thankfully the toppings are all excellent and kind of overcompensate for the crust.',
#   'Thanks Eklectic Pie!',
#   'Thanks for such a fun experience spinning the wheel too.',
#   "That's a plus plus, cheap and affordable, made fresh every time.",
#   "That's exactly what I said...give me all the meat.",
#   "That's only a 50% success rate!",
#   "That's such a great policy.",
#   "That's the theme of this whole experience.",
#   'The "Meaty Italiano" and "Besto Pesto Chicken".',
#   'The 7 inch is perfect for on person ...',
#   "The Besto Pesto Chicken was great too - I think in the future I'd ask for more pesto sauce though.",
#   'The Flame Thrower is my favorite.',
#   'The Italian and the cowboy bqq are really good ..',
#   'The atmosphere is fun.',
#   'The atmosphere is pleasant.',
#   'The atmosphere was super laid back and funky urban which gave off a great vibe, the staff was excellent and on their game, super welcoming and helpful.',
#   'The bathrooms were clean, tidy, and had a pleasant smell to them.',
#   'The best atmosphere!',
#   'The bottleneck at the counter is terrible.',
#   'The choco chip had more taste to it but the crumbles on the apple version were yummy.',
#   'The chocolate chip was like a flat, half-cooked cookie and the apple was like a pizza crust with apple topping and crumble.',
#   "The concept is fast personal pizza with your choice of a zillion items, or somebody else's choices from the wall of fame.",
#   'The cowboy barbeque pizza was delicious.',
#   'The crust itself is flimsy and tasteless.',
#   'The crust was light and airy, the toppings were superb, the pure cane sodas were on point.... And to top it off, the customer service was incredible!',
#   'The crust was really good, which is important.',
#   'The crust was thin which I liked, and everything was fresh and amazing.',
#   'The decor is also fun.',
#   'The desert pie was unexpectedly wonderful.',
#   'The dough is okay.',
#   'The employees are friendly.',
#   'The food came out fast and the staff were attentive.',
#   'The gal putting together the pizzas, pulled some raw chicken wings out of the fridge and put them on a tray to be baked.',
#   "The girl who made our pizzas got one of them wrong which wasn't realized until it was brought to our table because the wrong item was added after being baked.",
#   'The guy said..."I\'m busy making a pizza and don\'t have time to take a phone order."',
#   'The husband and I checked it out after some shopping in the complex.',
#   'The inside is cool, lots of interesting places to sit.',
#   'The instructional menu was so easy to read and comprehend.',
#   'The last 13 Reviews were 5 Star.',
#   'The line was getting long and people were becoming impatient.',
#   'The line was not that long, maybe 4-5 customers ahead of us but we waited in line for almost 30 minutes to order and pay for our food, then another 15 to get our food.',
#   'The meats had great flavor and the fresh mozzarella was really nice.',
#   'The music system was also off (inexplicably) so we waited in silence, painfully aware of the impatient sighs and chatter of all the guests now waiting in the slow building line behind us.',
#   'The owner was holding the door to greet customers which was very nice customer service he explained the concept him and his wife decided to implement into the restaurant and thanked us for coming.',
#   'The pie was excellent but could possibly need a little longer in the oven and the salad was great except for a few large lettuce pieces ( I try not to look like a crazy person stuffing in a huge bite when possible lol).',
#   'The pizza crust is pretty bad and I got balsamic dressing for my salad which is usually oil based, but this balsamic was like syrup.',
#   'The pizza did not look anything like the photos provided on yelp.',
#   'The pizza is ok, but depending on your taste, there are better pizzas out there.',
#   'The pizza is so thin and burned... sad face.',
#   'The pizza was delicious and my husband commented that he especially liked the pizza sauce.',
#   'The pizzas are always made fresh!',
#   'The place was not busy - there were about 5 people in line ahead of us.',
#   'The potato skin pizza had intrigued me when I looked at their menu online, and living up to its name, it does taste like potato skins which goes GREAT with the beer.',
#   'The prefab flavor combinations and idea boards really elevate your pie to the next level.',
#   'The price is right and the beer is cold.',
#   'The prices are good and the ingredients fresh.',
#   'The product was amazing, we had three pies.',
#   "The quality of food itself was good; no complaints there but I just don't see is frequenting this place after our first impression.",
#   'The sauce is super sweet.',
#   'The sauce was great and not overly salty or oily (I hate that) and had tons of flavor.',
#   'The service is nice, inside decor is cute.',
#   'The service, prices, atmosphere and food are phenomenal.',
#   'The set up is much like Blaze Pizza in CA.',
#   'The soda they have is amazing!',
#   "The staff didn't acknowledge me.",
#   'The staff has absolutely no hustle.',
#   'The staff is also very informative on what certain ingredients are and how they taste, and they have local brewery beers on hand that are affordable as well.',
#   'The staff is super nice and the atmosphere is really cute.',
#   'The staff member just said, "Sorry, we don\'t have a good system".',
#   'The staff was friendly and over the top excited to help out.',
#   'The staff was really nice and the interior of Eklectic was very nice.',
#   "The staff was very accommodating and didn't even blink an eye to what I was requesting.",
#   'The toppings are so fun to pile on, their fountain drinks are great and I love their child tours they have every month.',
#   'The toppings are the best part of their menu.',
#   'The workers at Pie Five Pizza Company are so great.',
#   'The workers looked like they were moving in slow motion.',
#   'The worst part of my visit were the salad dressings, they tasted very low quality & definitely not homemade and only four to choose from.',
#   'Their Caesar salad dressing is one of the best I have had.',
#   "Their drinks are All natural pure cane sugar soft drinks, Boylan's, and China Mist Iced Teas.",
#   'Then we got the cookie smasher *WARNING NO ICE CREAM ON THE COOKIE * BUT!!',
#   'Then we were immediately met at the front by (I believe) the manager and he welcomed us.',
#   'There are other locations that you can go to though.',
#   'There is no pizza feel to the place at all .',
#   'There was a couple behind us who was pointing at one of the ladies placing the sauce on top of the pizza.',
#   "There wasn't a long wait for the pizzas to be baked and then they were hand delivered to our table.",
#   'There were individuals cleaning up tables, serving food, and asking patrons how their meal was.',
#   'These guys have the best pizza in town!',
#   'They also have a gluten free crust.',
#   'They also have a limited selection of wines and beers.',
#   'They also have a rewards program which is great!',
#   "They also have birch beer soda yummy town U.S.A. Best pizza I've had in awhile.",
#   'They also have both gluten-free crust and dairy free options, My family and I have absolutely loved this place since it opened a few months ago.',
#   'They also have subs (3 choices and they all are $7.49), salads ($7.29), and dessert pies ($2.99).',
#   'They are slow All five in my party tried a different pizza and we loved them all!!',
#   'They are very accommodating when you tell them about dietary restrictions.',
#   'They could definitely use some customer service training.',
#   'They did a nice job.',
#   "They do use nice ingredients and that's about all that's good about the food.",
#   'They even paid special attention to my 4 year old daughter.',
#   'They have a great lunch special.',
#   'They have delicious unique soda we got the root beer which k think has just a hint of vanilla but was oh so good.',
#   'They let us sample each one and I chose the Koffee Kolsch!',
#   'They make great, insightful recommendations.',
#   'They need to be re-trained to ensure speedy service to guests.',
#   'They offer craft sodas and an eclectic beer menu that changes from week to week.',
#   'They opted for strange unheard of cans of beer and "hip" drinks like izze.',
#   'They ran like a well oiled machine.',
#   "They serve Boylan's brand sodas, and some iced teas.",
#   'They try to use all fresh and organic ingredient and hormone free meats, when available.',
#   "They were good but I wish I didn't feel like I had to try something completely new.",
#   'They were made to perfection!',
#   'Things to improve: The staff are a little slow.',
#   'This is my second review.',
#   'This is the only pizza I truly love the crust is awesome and the people behind the counter are so happy and helpful.',
#   'This pizza is so bomb, I love the thin crust and there sauce..',
#   'This place is awesome!',
#   'This place is great!',
#   'This place is perfect.',
#   'This place is so yummy!',
#   'This place was awesome!',
#   'Tip: Get on their mailing list and use their rewards program and you will get all kinds of deals sent your way.',
#   'Tons of toppings and no extra charge no matter what you put on your pizza.',
#   'Too busy to sell a pizza???',
#   'Tried out a new place.',
#   'Tried this place for the first time.',
#   'Two stars.',
#   'UNREAL wait time.',
#   'Unfortunately I have to drive about 15 minutes away to get to it.',
#   'Very fast and friendly service.',
#   'Very friendly staff and great food!',
#   'Very good size personal pizzas and very filling!',
#   'Very yummy!',
#   'View it as something else because it does not compare.',
#   'Visit their Chandler location.',
#   "Visited based on a friend's recommendation, E.Pie definitely didn't disappoint!",
#   'We actually just tried Fired Pie a few weeks ago and loved the concept.',
#   "We all can't wait to go back!",
#   "We also loved the monday night prices-you get a whole pizza for only $5, it might actually be all day I can't remember.",
#   'We also ordered 2 dessert pizzas that were the bomb!!!!',
#   'We both ordered the 11" Build your own ($7.99 ea.)',
#   'We declined as half of the wrong one was already eaten.',
#   "We didn't know what we were really getting into.",
#   'We enjoy coming here.',
#   'We got the 11" Cowboy BBQ & 11" Flame Thrower.',
#   'We got the Italian pizza and it was delicious!',
#   'We got there an hour before closing time on a Thursday.',
#   'We have been coming back ever since!',
#   'We have order threw them online for our work lunch and I love that you can order WHATEVER YOU WANT!',
#   'We have ordered the cookie pizza before too.',
#   'We informed him of the error and he did offer to make a new pizza.',
#   'We look forward to the fresh ingredients and consistent great pizza every time!',
#   'We love coming here for lunch!',
#   'We made it through the line quickly, and were provided our meals in probably less than 15 minutes.',
#   'We ordered two and brought home leftovers.',
#   'We ordered two create your own pizzas and two desserts (see photos for descriptions).',
#   'We ordered two pizzas, pepperoni and meaty, both 11" and were underwhelmed.',
#   'We used a promo code so paid about $13 for two 11" pizzas which wasn\'t bad.',
#   'We walked in and noticed what a cool environment there was right away.',
#   'We were VERY impressed.',
#   'We were the only two people in the restaurant when we ordered.',
#   'We will be back!',
#   'We will definitely be back!',
#   'We will do without the desserts next time (they were good, not great).',
#   "We've eaten there 3 times, and really look forward to it.",
#   'We\'ve tried a handful of "build your own" pizza places and this one by far surpasses its competition.',
#   'Welcome to the area Eclectic Pie!!!',
#   'Well done Eklectic!',
#   'Went here three times the week we discovered it.',
#   'What an amazing place.',
#   'What else can I say.',
#   'What makes it awesome is the caliber of connectedness and service.',
#   'What?!',
#   'When I asked about the cheese, the girl that made my pizza who suffers from Gluten and dairy intolerance made an entire pizza just for my little boy so that I could take it home for him to try.',
#   'When I picked it up, I asked the employee about it and she said "oh, I think they changed that", I said no they have not changed it in the computer to which her response was "oh".',
#   'Wine Country Pizza Alfredo Sauce, mozzarella, gorgonzola, caramelized onion & walnuts topped with baby spinach leaves & balsamic fig vinaigrette.',
#   'Wish it was better.',
#   'Wish they would let us order over the phone as we tried but they pointed us to creating an on-line account so ended up going in.',
#   'Would have loved some balsamic or raspberry vinaigrette.',
#   'Wow.',
#   'YUM!',
#   'YUMMMM is the best way to describe this place.',
#   "Yes they were friendly, filled with energy...MAYBE they are just getting into the groove of things since it is now a 3 week old restaurant but sheesh get some speed in since there's a line!",
#   'You can add as many toppings as you want, all for the same price!',
#   'You can add as many toppings as you want, in any combination to make your pie.',
#   'You can also get salads.',
#   'You can have any of that on a pizza; or choose one of their unique specialties.',
#   'You can have as many toppings on your pizza as you like - no extra charge.',
#   'You can tell that the employees really like working here.',
#   "You can't beat the price for the kid's meal, which includes a drink with the 7 in cheese pizza.",
#   'You choose your crust size - gluten free is available - (7-inch $5.49 or 11-inch $7.99), sauce, cheese(s) meats, veggies, and fresh toppings.',
#   'You get to choose your own size, 7" or 11" and then choose your own toppings.',
#   'You walk up to order your pizza pick your toppings and they put it on a piece of dough that is half dried out.',
#   'You will not find your typical coke or pepsi selection.',
#   'You would have to order 3 pizzas just to get full, not worth the price, its a pizza subway!!!',
#   'and the price is great.',
#   'baked right in front of ne.',
#   'think Subway of pizza) this one is definitely the best.'}}
