# %%
import re
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk import tokenize 
import pandas as pd
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def read_from_file(filename):
    df = pd.read_csv(filename, index_col=0)
    return df

# Data exploration
def data_exploration(dataset):
    dataset.isnull().sum() # all zeros
    dataset.business_id.nunique() # 284
    dataset.name.nunique() # 271
    dataset.groupby('name').size().sort_values(ascending=False)
    dataset.groupby('business_id').size().sort_values(ascending=False).head()

def clean_dataset(dataset):
    reviews_by_businessid = dataset.groupby('business_id').apply(lambda x: x['text'].unique()).to_frame(name='review_list')
    reviews_by_businessid = reviews_by_businessid.reset_index()
    reviews_by_businessid['review_list'] = reviews_by_businessid['review_list'].apply(lambda x: ' '. join(x))
    # reviews_by_businessid['review_length'] = reviews_by_businessid['review_list'].apply(len)
    # reviews_by_businessid.review_length.sort_values(ascending=False)
    return reviews_by_businessid

# expensive
def initial_sent_clean(sent):
    sent = re.sub("((\S+)?(http(s)?)(\S+))|((\S+)?(www)(\S+))|((\S+)?(\@)(\S+)?)", " ", text)
    sent = re.sub("[^a-zA-Z ]", "", text)
    sent = text.lower()
    return sent

def sent_preprocess(sent):
    tokens = [word for word in word_tokenize(sent)]
    filtered_tokens = [token.lower() for token in tokens if re.match("^[A-Za-z-]*$", token)]
    lemmatized_tokens = [lemmatizer.lemmatize(t, 'v') for t in filtered_tokens]
    final_tokens = [s for s in lemmatized_tokens if s not in stop_words]
    return ' '.join(final_tokens)

def preprocess(reviews_by_businessid):
    # remove head() later
    reviews_dict = dict(zip(reviews_by_businessid.head(1).business_id, reviews_by_businessid.head(1).review_list))
    sentences_dict = {}
    processed_sent_dict = {}
    
    for bi, text in reviews_dict.items():
        sentences_dict[bi] = sent_tokenize(text)
    
    for bi, sent_list in sentences_dict.items():
        new_sent_list = []
        
        for sent in sent_list:
            processed_sent = sent_preprocess(sent)
            new_sent_list.append(processed_sent)
        
        processed_sent_dict[bi] = new_sent_list
    
    return processed_sent_dict

# %%
fn = "csv_reviews_mesa.csv"
mesa = read_from_file(fn)

# change assignment later
selected_businesses = mesa
reviews_by_businessid = clean_dataset(selected_businesses)

reviews = preprocess(reviews_by_businessid)
res = select_pos_reviews(reviews)
# Out:
# 893

# %%
def select_pos_reviews(reviews):
    pos_reviews_dict = {}
    
    sid = SentimentIntensityAnalyzer()
    
    for bi, sent_list in reviews.items():
        pos_sentences = []
        
        for sentence in sent_list:
            ss = sid.polarity_scores(sentence)
            
            #pos_score = ss['pos']
            #neg_score = ss['neg']
            #neu_score = ss['neu']
            compound_score = ss['compound']
        
            if compound_score >= 0.05:
                pos_sentences.append(sentence)
        
        pos_reviews_dict[bi] = pos_sentences
        
    return pos_reviews_dict

res = select_pos_reviews(reviews)
res
# Out:
# {'-3oxnPPPU3YoxO9M1I2idg': ['try place first time pizza really good',
#   'however service good',
#   'could definitely use customer service train',
#   'definitely best make type pizza place beat mod pizza mile',
#   'ingredients fresh desserts delicious',
#   'pizza bomb love thin crust',
#   'italian cowboy bqq really good',
#   'pizza flavor good customize way want',
#   'inch perfect person',
#   'love everything place',
#   'toppings fun pile fountain drink great love child tour every month',
#   'love place',
#   'like subway pizzas pay one price heap toppings hearts delight nine buck',
#   'sure guy stay business guilt always end buy drink side wing skin fantastic',
#   'tip get mail list use reward program get kinds deal send way',
#   'apologetic friendly',
#   'success rate',
#   'quality food good complaints see frequent place first impression',
#   'impress',
#   'things pretty quiet mean line faster pizza mouth',
#   'logo outside super bright yellow eye-catching even',
#   'inside things cool industrial unusual',
#   'line get option choose pizza size pick sauce mix variety awesome ingredients extra charge',
#   'part want go nut part lazy really hungry choose go different pre-made pies wall fame',
#   'dessert go around next time sure',
#   'drink soda boyfriend comment soda really good corporate brand like coke pepsi instead brand never hear call boylan',
#   'fan',
#   'anyway wait felt like minutes bam',
#   'meat-lover definitely favor meaty italiano',
#   'besto pesto chicken great - think future ask pesto sauce though',
#   'would love try one spicy options boyfriend white kid vermont',
#   'clearly solo visit next go-around',
#   'around staff super friendly make order process clear easy',
#   'price affordable pizzas crisp fresh',
#   'eat twice first time get wine country delicious pear spinach gorgonzola pizza',
#   'pepper expect delicious get tutti pie fruitti good finish whole thing bf ussually eat much good pass',
#   'delicious unique soda get root beer k think hint vanilla oh good',
#   'also birch beer soda yummy town best pizza awhile',
#   'great place good quality toppings',
#   'pro tip ask extra cook load pies cowboy barbeque pizza delicious',
#   'employees friendly',
#   'atmosphere pleasant',
#   'highly recommend place',
#   'order online get confirmation would ready',
#   'look minutes order find warm oven',
#   'staff member say sorry good system',
#   'fiance come across project pie vegas fell love concept saw open right street house',
#   'owner hold door greet customers nice customer service explain concept wife decide implement restaurant thank us come',
#   'employees nice inside decorate perfectly',
#   'plain pizza person get pepperoni fiance get meat lovers enjoy pizza although come soggy floppy',
#   'good would drive another place concept next time',
#   'come busy morning run errands figure give eklectic pie chance',
#   'order two pizza play safe visit review mix',
#   'service nice inside decor cute',
#   'far pizza go sauce bite sweet taste crust thin',
#   'next visit wo safe',
#   'family mix taste bud come pizza sure would good',
#   'easy find suggestion would sign lead right pizza place',
#   'thing would slow day time music play little lower almost yell service worker',
#   'absolutely love place',
#   'pizza unlimited toppings perfect split pizza dessert side',
#   'great atmosphere good quality toppings friendly staff',
#   'also reward program great',
#   'highly recommend place',
#   'best pizza town',
#   'top dark beer',
#   'heaven',
#   'fresh ingredients great taste pizza beer soda real cane sugar',
#   'price great',
#   'order throw online work lunch love order whatever want',
#   'amaze place food great',
#   'atmosphere drink selection real winner',
#   'endless toppings also cool way personalize pizza pie',
#   'pizza ok depend taste better pizzas',
#   'staff friendly top excite help',
#   'overall would recommend check place',
#   'wow expect variety toppings sauce fresh amd delicious sauce impressive mighty tasty mix basil pesto cilantro jalapeno lime',
#   'woth fresh mozzarella grade mozzarella sun dry tomatos red onions fesh basil red pepper mushroom roast garlic',
#   'amaze pie fresh ingredients deliver amazingly friendly staff',
#   'amaze place',
#   'employees fun talk',
#   'make great insightful recommendations',
#   'order pizza amaze flavor',
#   'great crust mind make break pizza great flavor',
#   'go grab bite eat low expectations since best luck style restaurant surprise taste variety options',
#   'guide tyler help make wonderful pizza',
#   'johnathan leesha help answer question entire staff seem knowledgeable friendly',
#   'really cool spot definitely back',
#   'craft soda fresh teas huge surprise',
#   'impress',
#   'usually go fire pie mod pizza place better place',
#   'soda drinker use natural sugar rather high fructose corn srp taste better regular soda complaints',
#   'order two create pizzas two desserts see photos descriptions',
#   'add toppings combinations great newbie indecisive',
#   'actually try fire pie weeks ago love concept',
#   'like top variety better eklectic head desserts much bigger could easily share',
#   'chocolate chip like flat half-cooked cookie apple like pizza crust apple top crumble',
#   'choco chip taste crumble apple version yummy',
#   'sign loyalty program phone via website immediately eligible free dessert',
#   'give name loyalty account',
#   'definitely back',
#   'fresh ingredients great options',
#   'without desserts next time good great',
#   'kid picky love',
#   'good nothing brand new industry good pizza back',
#   'great step hole wall pizza joint',
#   'dare say best pizza place ever',
#   'best atmosphere',
#   'everyone friendly happy make suggestions',
#   'delicious food',
#   'like chipolte pizza without salminola whatever',
#   'good',
#   'really like concept staff super nice could hear word say',
#   'kind annoy whatever',
#   'order salad thrill able put many toppings like',
#   'however like meats ice cold',
#   'would love balsamic raspberry vinaigrette',
#   'really healthy choices end take salad home use dress another restaurant',
#   'good pizza make quickly without skimp quality',
#   'great selection boylan sodas',
#   'love pizzas favorite cowboy bbq pizza',
#   'great atmosphere',
#   'beer pizza thumb delicious ever daughters new favorite pizza maya meat trio',
#   'acropolis also delicious birch beer fountain fantastic',
#   'best pizza joint around',
#   'sorry joke rest pizza joint around close',
#   'one touch amaze pies eklectic pie',
#   'every time wife go everyone happy smile',
#   'forget order soda root beer far best around',
#   'fantastic ingredients friendly service make perfect business plan',
#   'excellent open day',
#   'fast friendly service',
#   'pizzas great',
#   'crust really good important',
#   'come perfect',
#   'meats great flavor fresh mozzarella really nice',
#   'girlfriend make pizza pesto base sauce say really good',
#   'say great well',
#   'nice person make pizza change gloves make sure gluten make gluten-free pizza',
#   'cook perfection ready eat three minutes',
#   'restaurant clean food good value money',
#   'excellent customer service',
#   'good environment clean unique soda selections delicious pizza',
#   'definitely recommend back',
#   'love place',
#   'great pizza awesome price always top notch service',
#   'look forward grab pie minutes good food',
#   'even vegan options dairy free cheese',
#   'also gluten free crust',
#   'atmosphere fun',
#   'wow',
#   'service everyone great',
#   'every employee helpful good people',
#   'product amaze three pies',
#   'amaze',
#   'workers pie five pizza company great',
#   'pizza crust pretty bad get balsamic dress salad usually oil base balsamic like syrup',
#   'even great service would go back',
#   'excellent pizza',
#   'love charge top one price',
#   'great policy',
#   'guy make pizzas obviously love job guess treat people well',
#   'taste great nice thin crust everything test fresh',
#   'highly recommend try',
#   'wish one east mesa',
#   'pizza good gluten free crust well',
#   'overall walk line pick toppings nice thing toppings include price crust size load',
#   'price normal would consider family mom dad kid include pint ipa enjoy life good know enjoy',
#   'place awesome',
#   'get italian pizza delicious',
#   'love sauce extra help toppings',
#   'crust really thin crispy good well',
#   'service staff nice clean plat',
#   'also leave hand frisbee water bottle logo',
#   'back sure',
#   'eklectic pie staff friendly atmosphere fun food good',
#   'come officially open enjoy two free pies',
#   'add many toppings want combination make pie',
#   'toppings fresh vary delicious',
#   'since get exactly want really enjoy pie',
#   'since close house local movie theater back bring friends',
#   'order three pies good flavor good crust',
#   'wish would let us order phone try point us create on-line account end go',
#   'staff friendly price reasonable back look forward try beverages adult mist teas',
#   'happy give place five star',
#   'fancy fresh fast great employees consistently',
#   'always look healthy choices really happy find place',
#   'first let say love build pizza place - trend someone food allergies make order easy',
#   'ask want',
#   'lot around valley eklectic pie favorite - best choice top anywhere',
#   'love bacon pull pork roast potatoes',
#   'also great crust',
#   'decor also fun',
#   'excellent pizza good service',
#   'soda amaze',
#   'like creme soda personally',
#   'definitely place come often',
#   'place yummy',
#   'flame thrower favorite',
#   'good flavor',
#   'everyone work amaze',
#   'thank fun experience spin wheel',
#   'first time - try gluten-free crust margarita pizza love',
#   'definitely back try',
#   'tasty pizzas fresh ingredients friendly service craft brew make place trifecta excellence',
#   'start good - food undeniably fantastic',
#   'taste great hot fresh',
#   'dont even get start pie - best',
#   'need re-trained ensure speedy service guests',
#   'sure need ovens employees espresso machine get staff move something give',
#   'love place stapley location close',
#   'quick delicious pizza way',
#   'highly recommend pizza restaurant',
#   'wine country pizza alfredo sauce mozzarella gorgonzola caramelize onion walnuts top baby spinach leave balsamic fig vinaigrette',
#   'cowboy barbeque pizza delicious',
#   'employees friendly',
#   'atmosphere pleasant',
#   'highly recommend place',
#   'right away greet employees really like interior',
#   'nice job',
#   'funky interest',
#   'fantastic selection local brew wine choose well pizza combinations wall fame creative',
#   'saw several want try',
#   'potato skin pizza intrigue look menu online live name taste like potato skin go great beer',
#   'meaty italiano half good well lot good quality meats',
#   'care crust',
#   'nice thickness totally bland',
#   'miss kind garlicky buttery season flavor crust go brick oven flavor char',
#   'thankfully toppings excellent kind overcompensate crust',
#   'enjoy first visit husband really enjoy leftovers',
#   'definitely back',
#   'enjoy come',
#   'love load pizza veggie toppings',
#   'always come delicious',
#   'make great place eat family',
#   'love soda offer',
#   'absolutely delicious',
#   'really appreciate gf pizza option family member celiac disease',
#   'finally go place much larger expect nice atmosphere friendly helpful employees best food great',
#   'price reasonable definitely go back',
#   'place nice interior friendly staff',
#   'price good ingredients fresh',
#   'lunch special pie side ceasar salad',
#   'pie excellent could possibly need little longer oven salad great except large lettuce piece try look like crazy person stuff huge bite possible lol',
#   'keep see place would drive always want try',
#   'would hear yummy decide get deliver grub hub',
#   'crust thin like everything fresh amaze',
#   'also order side salad bunch toppings miss one top',
#   'would definitely recommend place',
#   'good job guy',
#   'thank',
#   'good',
#   'good excellent flavor',
#   'go day use birthday loyalty reward',
#   'could ask place free pizza birthday',
#   'definitely return',
#   'pizza great',
#   'restaurant clean staff friendly',
#   'like price',
#   'welcome area eclectic pie',
#   'cheese pepperoni ok',
#   'sauce excellent cheese ok good horrible',
#   'crust wall fame pizza',
#   'homemade cola products fountain really good',
#   'sauce -excellent cheese- crust- ok crazy expensive ok value enjoy custom pizzas',
#   'good basil pesto pizza',
#   'like serve wine craft beers',
#   'inside cool lot interest place sit',
#   'awesome pizza',
#   'perfect size',
#   'yummy',
#   'wife come first time love',
#   'pizza awesome staff',
#   'definitely back',
#   'place perfect',
#   'get exactly want within decent amount time',
#   'desert pie unexpectedly wonderful',
#   'super creative love local ingredients',
#   'thank owner wonderful mouth play-land',
#   'go straight toppings wear gloves cover raw chicken',
#   'wine country besto pesto gluten free pizza plus bunch extra meat veggies cheese',
#   'clean trendy decor',
#   'instructional menu easy read comprehend',
#   'user friendly',
#   'clean table variety type like booths high vs low top table',
#   'love place',
#   'price perfectly',
#   'would recommend unique spot anyone',
#   'great place',
#   'service awesome fresh ingredients organic',
#   'great price great staff amaze taste pizza',
#   'love place place go pizza days',
#   'service great',
#   'tell employees really like work',
#   'friendly helpful',
#   'compare like pizza joint',
#   'think subway pizza one definitely best',
#   'fresh ingredients great price crust good -- little thin taste next time get double crust buck',
#   'oh beer wine choice awesome',
#   'local craft beers tap little hh top rat local win little also hh',
#   'pretty good little place',
#   'standard price size choice toppings want additional charge',
#   'pizza good',
#   'nothing spectacular also nothing complain',
#   'fantastic service top',
#   'tyler leija run restaurant like well-oiled machine knowledge products craft beers impressive',
#   'tatyana leija hayley stout unbelievable behind counter',
#   'explain process things work virgin eklectics ingredients use even allow sample stuff wife order',
#   'restaurant like everywhere',
#   'great people outstanding customer service delicious food',
#   'kudos',
#   'excellent pizza service',
#   'pizza truly love crust awesome people behind counter happy helpful',
#   'love',
#   'appreciate still love place',
#   'really like feel place',
#   'pizzas cook quickly service great',
#   'great lunch special',
#   'caesar salad dress one best',
#   'suggest place friends coworkers without hesitation',
#   'friend say good',
#   'drink soda think cool serve something big two soda company',
#   'love place',
#   'entree salad come whatever want italian sausage pepperoni slice mozzarella blue cheese crumble parmesan cheddar carmelized onions mushroom red pepper chop tomatoes raw red onions black green olives artichokes',
#   'good',
#   'relax atmosphere',
#   'serve boylan brand sodas ice teas',
#   'plus side birch beer kind like root beer',
#   'say super impress',
#   'sauce great overly salty oily hate tons flavor',
#   'love veggie toppings ton veggies addition vegan cheese great',
#   'also love get addtional toppings like spinch basil vinaigrette etc pizza come oven',
#   'another thing really appreciate employee switch gloves make pizza contaminate mine previous pizza',
#   'staff super nice atmosphere really cute',
#   'also appreciate arizona win carry',
#   'happy come across little gem',
#   'love pizza',
#   'get pizzas whatever want super affordable',
#   'husband really enjoy good beer greatest selection',
#   'sooo delicious',
#   'pretty much add every vegetable pizza cost',
#   'fresh basil finisher balsamic fig sauce tasty',
#   'recommend wine country mine besto pesto',
#   'everything amaze',
#   'pepper favorite',
#   'local craft beer natural sodas',
#   'highly recommend pizza restaurant',
#   'wine country pizza alfredo sauce mozzarella gorgonzola caramelize onion walnuts top baby spinach leave balsamic fig vinaigrette',
#   'cowboy barbeque pizza delicious',
#   'employees friendly',
#   'atmosphere pleasant',
#   'highly recommend place',
#   'guy best pizza town',
#   'add many toppings want price',
#   'try use fresh organic ingredient hormone free meats available',
#   'also gluten-free crust dairy free options family absolutely love place since open months ago',
#   'staff always unbelievably friendly ingredients fresh delicious atmosphere really nice',
#   'local cane sugar sodas also really nice surprise',
#   'also appreciate occasional coupons mail least month great value special',
#   'return recommend often',
#   'yes hello would like cheese pizza everything eat build put pizza top extra charge place work',
#   'impress',
#   'delicious pizza extra toppings could want',
#   'get roast garlic heavenly',
#   'get potato skin pizza omg amaze',
#   'hubby little one get something different perfect us',
#   'bad place pizza best either',
#   'walk like husband point want heavy food small pizza small salad job',
#   'italian white wed good although could cook little longer husband gyro think good',
#   'impress quality customer service type food offer delicious',
#   'amaze see even offer dairy free cheese daiya brand child dairy intolerance',
#   'go beyond make us feel welcome',
#   'also love monday night prices-you get whole pizza might actually day ca remember',
#   'either way definitely back',
#   'thank eklectic pie',
#   'use nice ingredients good food',
#   'take look around order like hospital cafeteria even pizza oven place put oven conveyer belt pop side like easy bake oven year old home',
#   'like say ingredients good crust',
#   'employees nice slow',
#   'good first impression love real gluten-free option pizza',
#   'even pay special attention year old daughter',
#   'impress go back',
#   'wish deliver',
#   'love come lunch',
#   'everyone super friendly pizza delicious',
#   'look forward fresh ingredients consistent great pizza every time',
#   'atmosphere super lay back funky urban give great vibe staff excellent game super welcome helpful',
#   'whole place clean busy saturday night',
#   'pizza buffalo sauce fresh cheese chicken',
#   'impress walk leave get great service comfortable din experience phenomenal pizza',
#   'definitely new pizza place',
#   'fun watch employmees make pizza almost like chipotle pizza',
#   'also drink hip cool tasty',
#   'love love love love love',
#   'appreciate competition diy pie arena',
#   'taste point along quality enjoy everything eclectic pie offer',
#   'mod pizza marry in-n-out burger son local craft brewery get together mom-and-pop corner store daughter two kid hook think offspring would look lot like eklectic pie',
#   'concept fast personal pizza choice zillion items somebody else choices wall fame',
#   'make awesome caliber connectedness service',
#   'beer soda selection ice cake enjoy creative welcome touch curious decor music',
#   'definite must-visit',
#   'love look',
#   'friendly staff great food',
#   'try love',
#   'good size personal pizzas fill',
#   'still amaze',
#   'care food',
#   'like idea behind flaw',
#   'toppings best part menu',
#   'care sauce either',
#   'slow five party try different pizza love',
#   'get ready order dessert sure love ep',
#   'everything fresh make order',
#   'besto pesto favorite',
#   'servers friendly location clean',
#   'highly recommend',
#   'nicely decorate place',
#   'chairman chow pizza pretty tastey',
#   'wife meat lovers',
#   'ok best',
#   'black cherry cola good',
#   'pizzas sodas please mistake good pizza local pizzeria',
#   'interest din concept end product impress',
#   'would order pizzas get full worth price pizza subway',
#   'employees friendly go',
#   'whole place invite',
#   'toppings margarita pizza delicious pizza undercooked',
#   'make disappoint end good first impression',
#   'yummmm best way describe place',
#   'buikd get straight menu',
#   'either way cant lose',
#   'like close',
#   'usually pizza really good service amaze buy pizzas one suppose finisher get home look pizza realize',
#   'girl make pizza nice enough',
#   'go back re-explain want finally give right box',
#   'wish staff bother listen',
#   'opt strange unheard beer hip drink like izze',
#   'soda machine feature strange flavor like cream ginger',
#   'good wish feel like try something completely new',
#   'visit base friend recommendation definitely disappoint',
#   'staff friendly efficient order wine country pesto chicken pizza',
#   'wine country favorite two',
#   'definitely back',
#   'thank yelp',
#   'seriously one best pizza experience ever',
#   'crust light airy toppings superb pure cane sodas point top customer service incredible',
#   'thing wish experience',
#   'well eklectic',
#   'many place pop like pieology among favorite plentiful selection toppings',
#   'ekletic pie among top favorite ambiance unique comfortable',
#   'top selection good exception miss garlic',
#   'state first time sure get',
#   'love wide variety food potato skin sandwich dessert also love play card give mark order number',
#   'drink okay teas pepsi cream sodas rootbeer',
#   'everything pretty good taste price wise',
#   'impress pizza',
#   'pizza look anything like photos provide yelp',
#   'since order online first order receive free dessert choose pie -- glad pay taste terrible',
#   'however order better pizza place choose',
#   'wife eat first time thoroughly impress',
#   'walk notice cool environment right away',
#   'immediately meet front believe manager welcome us',
#   'catch us surprise go menu order go good detail',
#   'blow away awesome customer service treat us like customers entire world',
#   'go order pizzas staff make pies also friendly make sure several time order right',
#   'long wait pizzas bake hand deliver table',
#   'food absolutely delicious price great',
#   'wife come back time time recommend place everyone know numerous type pizza place pop valley',
#   'good fun',
#   'party come order different pizza sample one another',
#   'back kid like better',
#   'workers look like move slow motion',
#   'awesome could build pizza like mod',
#   'great seperation',
#   'seem close stapley location yet chance go chandler',
#   'place great',
#   'pizzas always make fresh',
#   'fresh ingredients great service',
#   'always clean',
#   'plus plus cheap affordable make fresh every time',
#   'staff also informative certain ingredients taste local brewery beers hand affordable well',
#   'great pizza great price',
#   'good specials m-w',
#   'friendly staff',
#   'quick easy tasty right size everyone pizza',
#   'gluten free crust pizza best crust ever',
#   'usually taste like cardboard love put whatever want extra charge',
#   'definitely come anytime crave pizza',
#   'cool concept',
#   'like subway pizza',
#   'actually really good',
#   'great bunch people ca decide pizza toppings',
#   'huge fan mod pizza',
#   'meat love extra',
#   'love different ingredients seem blow custom pizza place water pizza restaurant',
#   'wish however offer ranch side end',
#   'since offer salads make clear',
#   'love interior place',
#   'modern homey well',
#   'atmosphere really feel like family atmosphere',
#   'families eat together owners seem anyways would mingle laugh along everyone',
#   'dough okay',
#   'also appreciate walk counter grab pizza rather take atmosphere bring table',
#   'things improve staff little slow',
#   'couple behind us point one ladies place sauce top pizza',
#   'know better would like year old try place sauce',
#   'yes friendly fill energy maybe get groove things since week old restaurant sheesh get speed since line',
#   'run like well oil machine',
#   'everyone pleasant engage customers happy hard work individuals',
#   'set much like blaze pizza ca',
#   'choose crust size - gluten free available - sauce cheese meats veggies fresh toppings',
#   'many toppings pizza like - extra charge',
#   'drink natural pure cane sugar soft drink boylan china mist ice teas',
#   'also limit selection win beers',
#   'make perfection',
#   'individuals clean table serve food ask patrons meal',
#   'bathrooms clean tidy pleasant smell',
#   'definitely bring friends family co-workers joint',
#   'wow',
#   'maybe ingredients fresh would matter',
#   'sure ingredients fresh byop place',
#   'c basically meat lovers',
#   'add marinara sausage pepperoni meatball fresh mozz',
#   'sound good right',
#   'would crust like wet piece lavosh',
#   'soggy support ingredients',
#   'taste toppings fine',
#   'put fresh roma fresh mozz mushroom onions marinara meatball mine',
#   'staff really nice interior eklectic nice',
#   'think interest soda machine dispense specialty soda recoginized brand',
#   'favorite brand nice staff',
#   'nice facility',
#   'clean din room',
#   'good toppings',
#   'place awesome',
#   'always quick fresh',
#   'staff friendly',
#   'relax atmosphere',
#   'pizza great besto pesto really good cowboy much bbq sauce quick delicious pizza way',
#   'highly recommend pizza restaurant',
#   'wine country pizza alfredo sauce mozzarella gorgonzola caramelize onion walnuts top baby spinach leave balsamic fig vinaigrette',
#   'cowboy barbeque pizza delicious',
#   'employees friendly',
#   'atmosphere pleasant',
#   'highly recommend place',
#   'vegetarian love place make food',
#   'felt like different sauce visible unless look menu around corner',
#   'finish stock pepperoni want food',
#   'first time ask pizza place people care pizza super thin',
#   'like thin pizza lot one thin bend toppings fall try pick slice',
#   'sauce super sweet',
#   'wish better',
#   'husband recently really enjoy',
#   'staff friendly atmosphere great',
#   'pizza delicious husband comment especially like pizza sauce',
#   'try orange blossom wheat beer husband try birch beer non-alcoholic similar root beer love choices',
#   'definitely visit place',
#   'best pizza town',
#   'get design choose favorites - mine sgt',
#   'oh super affordable',
#   'amaze pizza great fresh ingredients',
#   'cane sodas top notch customer service',
#   'serve quick hot delicious',
#   'also enjoy cup jasmine green tea',
#   'good pizza',
#   'great price',
#   'hate spell love place',
#   'plan skip crust carbs super thin crisp',
#   'yes',
#   'back want order grubhub beware',
#   'suggestion save delay get dinner order another pizza place use grubhub',
#   'sal gilbert pizza excellent choice']}
